# %% [markdown]
# Step 1: Importing Python Libraries

# %%
# Importing libraries

import pandas as pd
import numpy as np
import os
from datetime import datetime

# %% [markdown]
# Step 2: Importing Stock Datasets

# %%
# Importing Amazon stock data

path = r'/Users/matthewabrams/Desktop/Stocks Data/Stock Datasets/'
amazon = pd.read_csv(os.path.join(path, 'Original Stock Data/HistoricalData_Amazon.csv'), index_col = False)
amazon
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...          ...         ...         ...         ...         ...         ...
# 6883  2024-09-23  191.639999  194.449997  190.570007  193.880005  193.880005
# 6884  2024-09-24  194.270004  195.369995  190.130005  193.960007  193.960007
# 6885  2024-09-25  193.750000  193.949997  192.160004  192.529999  192.529999
# 6886  2024-09-26  194.309998  194.529999  189.539993  191.160004  191.160004
# 6887  2024-09-27  190.679993  190.899994  187.339996  187.970001  187.970001
#
#           Volume
# 0     1443120000
# 1      294000000
# 2      122136000
# 3      109344000
# 4      377064000
# ...          ...
# 6883    36993100
# 6884    43478900
# 6885    26391100
# 6886    36334900
# 6887    36002300
#
# [6888 rows x 7 columns]

# %%
# Importing Apple stock data

apple = pd.read_csv(os.path.join(path, 'Original Stock Data/HistoricalData_Apple.csv'), index_col = False)
apple
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098943
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093781
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086898
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089049
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091630
# ...           ...         ...         ...         ...         ...         ...
# 11035  2024-09-23  227.339996  229.449997  225.809998  226.470001  226.470001
# 11036  2024-09-24  228.649994  229.350006  225.729996  227.369995  227.369995
# 11037  2024-09-25  224.929993  227.289993  224.020004  226.369995  226.369995
# 11038  2024-09-26  227.300003  228.500000  225.410004  227.520004  227.520004
# 11039  2024-09-27  228.460007  229.520004  227.300003  227.789993  227.789993
#
#           Volume
# 0      469033600
# 1      175884800
# 2      105728000
# 3       86441600
# 4       73449600
# ...          ...
# 11035   54146000
# 11036   43556100
# 11037   42308700
# 11038   36636700
# 11039   34026000
#
# [11040 rows x 7 columns]

# %%
# Importing Meta stock data

meta = pd.read_csv(os.path.join(path, 'Original Stock Data/HistoricalData_Meta.csv'), index_col = False)
meta
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-05-18   42.049999   45.000000   38.000000   38.230000   38.115242
# 1     2012-05-21   36.529999   36.660000   33.000000   34.029999   33.927845
# 2     2012-05-22   32.610001   33.590000   30.940001   31.000000   30.906942
# 3     2012-05-23   31.370001   32.500000   31.360001   32.000000   31.903940
# 4     2012-05-24   32.950001   33.209999   31.770000   33.029999   32.930847
# ...          ...         ...         ...         ...         ...         ...
# 3105  2024-09-23  569.500000  573.979980  562.409973  564.409973  564.409973
# 3106  2024-09-24  566.679993  567.750000  554.190002  563.330017  563.330017
# 3107  2024-09-25  564.049988  576.880005  563.719971  568.309998  568.309998
# 3108  2024-09-26  575.729980  577.400024  562.349976  567.840027  567.840027
# 3109  2024-09-27  570.099976  570.840027  564.510010  567.359985  567.359985
#
#          Volume
# 0     573576400
# 1     168192700
# 2     101786600
# 3      73600000
# 4      50237200
# ...         ...
# 3105   12830700
# 3106   12993000
# 3107   16543400
# 3108   14400800
# 3109    9398400
#
# [3110 rows x 7 columns]

# %%
# Importing Microsoft stock data

microsoft = pd.read_csv(os.path.join(path, 'Original Stock Data/HistoricalData_Microsoft.csv'), index_col = False)
microsoft
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.059947
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062087
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063158
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.061552
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060482
# ...          ...         ...         ...         ...         ...         ...
# 9709  2024-09-23  434.279999  436.459991  430.390015  433.510010  433.510010
# 9710  2024-09-24  433.000000  433.350006  426.100006  429.170013  429.170013
# 9711  2024-09-25  429.829987  433.119995  428.570007  432.109985  432.109985
# 9712  2024-09-26  435.089996  435.299988  429.130005  431.309998  431.309998
# 9713  2024-09-27  431.519989  431.850006  427.470001  428.019989  428.019989
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9709    15128900
# 9710    17015800
# 9711    13396400
# 9712    14492000
# 9713    14896100
#
# [9714 rows x 7 columns]

# %%
# Importing Netflix stock data

netflix = pd.read_csv(os.path.join(path, 'Original Stock Data/HistoricalData_Netflix.csv'), index_col = False)
netflix
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 1     2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2     2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 3     2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 4     2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...          ...         ...         ...         ...         ...         ...
# 5621  2024-09-23  702.390015  712.250000  699.159973  705.369995  705.369995
# 5622  2024-09-24  706.630005  722.440002  704.450012  722.260010  722.260010
# 5623  2024-09-25  721.000000  725.119995  716.210022  721.559998  721.559998
# 5624  2024-09-26  724.729980  725.260010  701.719971  711.429993  711.429993
# 5625  2024-09-27  708.359985  710.710022  701.250000  707.349976  707.349976
#
#          Volume
# 0     104790000
# 1      11104800
# 2       6609400
# 3       6757800
# 4      10154200
# ...         ...
# 5621    3224300
# 5622    3565700
# 5623    2259800
# 5624    2833000
# 5625    2395600
#
# [5626 rows x 7 columns]

# %%
# Importing Telsa stock data

tesla = pd.read_csv(os.path.join(path, 'Original Stock Data/HistoricalData_Tesla.csv'), index_col = False)
tesla
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1     2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2     2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3     2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4     2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...          ...         ...         ...         ...         ...         ...
# 3582  2024-09-23  242.610001  250.000000  241.919998  250.000000  250.000000
# 3583  2024-09-24  254.080002  257.190002  249.050003  254.270004  254.270004
# 3584  2024-09-25  252.539993  257.049988  252.279999  257.019989  257.019989
# 3585  2024-09-26  260.600006  261.750000  251.529999  254.220001  254.220001
# 3586  2024-09-27  257.380005  260.700012  254.119995  260.459991  260.459991
#
#          Volume
# 0     281494500
# 1     257806500
# 2     123282000
# 3      77097000
# 4     103003500
# ...         ...
# 3582   86927200
# 3583   88491000
# 3584   65034300
# 3585   67142200
# 3586   70988100
#
# [3587 rows x 7 columns]

# %% [markdown]
# Step 3: Observing Datatypes for all datasets

# %%
amazon.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
apple.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
meta.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
microsoft.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
netflix.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
tesla.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# Step 4: Checking for missing values

# %%
amazon.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
apple.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
meta.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
microsoft.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
netflix.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
tesla.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# Step 4: Adding Additional Columns to Each Dataset

# %%
# Inserting column to each dataset where it points out the stock name
amazon.insert(0,'Stock_Name',"Amazon")
amazon
# Out:
#      Stock_Name        Date        Open        High         Low       Close  \
# 0        Amazon  1997-05-15    0.121875    0.125000    0.096354    0.097917
# 1        Amazon  1997-05-16    0.098438    0.098958    0.085417    0.086458
# 2        Amazon  1997-05-19    0.088021    0.088542    0.081250    0.085417
# 3        Amazon  1997-05-20    0.086458    0.087500    0.081771    0.081771
# 4        Amazon  1997-05-21    0.081771    0.082292    0.068750    0.071354
# ...         ...         ...         ...         ...         ...         ...
# 6883     Amazon  2024-09-23  191.639999  194.449997  190.570007  193.880005
# 6884     Amazon  2024-09-24  194.270004  195.369995  190.130005  193.960007
# 6885     Amazon  2024-09-25  193.750000  193.949997  192.160004  192.529999
# 6886     Amazon  2024-09-26  194.309998  194.529999  189.539993  191.160004
# 6887     Amazon  2024-09-27  190.679993  190.899994  187.339996  187.970001
#
#        Adj Close      Volume
# 0       0.097917  1443120000
# 1       0.086458   294000000
# 2       0.085417   122136000
# 3       0.081771   109344000
# 4       0.071354   377064000
# ...          ...         ...
# 6883  193.880005    36993100
# 6884  193.960007    43478900
# 6885  192.529999    26391100
# 6886  191.160004    36334900
# 6887  187.970001    36002300
#
# [6888 rows x 8 columns]

# %%
apple.insert(0,'Stock_Name',"Apple")
apple
# Out:
#       Stock_Name        Date        Open        High         Low       Close  \
# 0          Apple  1980-12-12    0.128348    0.128906    0.128348    0.128348
# 1          Apple  1980-12-15    0.122210    0.122210    0.121652    0.121652
# 2          Apple  1980-12-16    0.113281    0.113281    0.112723    0.112723
# 3          Apple  1980-12-17    0.115513    0.116071    0.115513    0.115513
# 4          Apple  1980-12-18    0.118862    0.119420    0.118862    0.118862
# ...          ...         ...         ...         ...         ...         ...
# 11035      Apple  2024-09-23  227.339996  229.449997  225.809998  226.470001
# 11036      Apple  2024-09-24  228.649994  229.350006  225.729996  227.369995
# 11037      Apple  2024-09-25  224.929993  227.289993  224.020004  226.369995
# 11038      Apple  2024-09-26  227.300003  228.500000  225.410004  227.520004
# 11039      Apple  2024-09-27  228.460007  229.520004  227.300003  227.789993
#
#         Adj Close     Volume
# 0        0.098943  469033600
# 1        0.093781  175884800
# 2        0.086898  105728000
# 3        0.089049   86441600
# 4        0.091630   73449600
# ...           ...        ...
# 11035  226.470001   54146000
# 11036  227.369995   43556100
# 11037  226.369995   42308700
# 11038  227.520004   36636700
# 11039  227.789993   34026000
#
# [11040 rows x 8 columns]

# %%
meta.insert(0,'Stock_Name',"Meta")
meta
# Out:
#      Stock_Name        Date        Open        High         Low       Close  \
# 0          Meta  2012-05-18   42.049999   45.000000   38.000000   38.230000
# 1          Meta  2012-05-21   36.529999   36.660000   33.000000   34.029999
# 2          Meta  2012-05-22   32.610001   33.590000   30.940001   31.000000
# 3          Meta  2012-05-23   31.370001   32.500000   31.360001   32.000000
# 4          Meta  2012-05-24   32.950001   33.209999   31.770000   33.029999
# ...         ...         ...         ...         ...         ...         ...
# 3105       Meta  2024-09-23  569.500000  573.979980  562.409973  564.409973
# 3106       Meta  2024-09-24  566.679993  567.750000  554.190002  563.330017
# 3107       Meta  2024-09-25  564.049988  576.880005  563.719971  568.309998
# 3108       Meta  2024-09-26  575.729980  577.400024  562.349976  567.840027
# 3109       Meta  2024-09-27  570.099976  570.840027  564.510010  567.359985
#
#        Adj Close     Volume
# 0      38.115242  573576400
# 1      33.927845  168192700
# 2      30.906942  101786600
# 3      31.903940   73600000
# 4      32.930847   50237200
# ...          ...        ...
# 3105  564.409973   12830700
# 3106  563.330017   12993000
# 3107  568.309998   16543400
# 3108  567.840027   14400800
# 3109  567.359985    9398400
#
# [3110 rows x 8 columns]

# %%
microsoft.insert(0,'Stock_Name',"Microsoft")
microsoft
# Out:
#      Stock_Name        Date        Open        High         Low       Close  \
# 0     Microsoft  1986-03-13    0.088542    0.101563    0.088542    0.097222
# 1     Microsoft  1986-03-14    0.097222    0.102431    0.097222    0.100694
# 2     Microsoft  1986-03-17    0.100694    0.103299    0.100694    0.102431
# 3     Microsoft  1986-03-18    0.102431    0.103299    0.098958    0.099826
# 4     Microsoft  1986-03-19    0.099826    0.100694    0.097222    0.098090
# ...         ...         ...         ...         ...         ...         ...
# 9709  Microsoft  2024-09-23  434.279999  436.459991  430.390015  433.510010
# 9710  Microsoft  2024-09-24  433.000000  433.350006  426.100006  429.170013
# 9711  Microsoft  2024-09-25  429.829987  433.119995  428.570007  432.109985
# 9712  Microsoft  2024-09-26  435.089996  435.299988  429.130005  431.309998
# 9713  Microsoft  2024-09-27  431.519989  431.850006  427.470001  428.019989
#
#        Adj Close      Volume
# 0       0.059947  1031788800
# 1       0.062087   308160000
# 2       0.063158   133171200
# 3       0.061552    67766400
# 4       0.060482    47894400
# ...          ...         ...
# 9709  433.510010    15128900
# 9710  429.170013    17015800
# 9711  432.109985    13396400
# 9712  431.309998    14492000
# 9713  428.019989    14896100
#
# [9714 rows x 8 columns]

# %%
netflix.insert(0,'Stock_Name',"Netflix")
netflix
# Out:
#      Stock_Name        Date        Open        High         Low       Close  \
# 0       Netflix  2002-05-23    1.156429    1.242857    1.145714    1.196429
# 1       Netflix  2002-05-24    1.214286    1.225000    1.197143    1.210000
# 2       Netflix  2002-05-28    1.213571    1.232143    1.157143    1.157143
# 3       Netflix  2002-05-29    1.164286    1.164286    1.085714    1.103571
# 4       Netflix  2002-05-30    1.107857    1.107857    1.071429    1.071429
# ...         ...         ...         ...         ...         ...         ...
# 5621    Netflix  2024-09-23  702.390015  712.250000  699.159973  705.369995
# 5622    Netflix  2024-09-24  706.630005  722.440002  704.450012  722.260010
# 5623    Netflix  2024-09-25  721.000000  725.119995  716.210022  721.559998
# 5624    Netflix  2024-09-26  724.729980  725.260010  701.719971  711.429993
# 5625    Netflix  2024-09-27  708.359985  710.710022  701.250000  707.349976
#
#        Adj Close     Volume
# 0       1.196429  104790000
# 1       1.210000   11104800
# 2       1.157143    6609400
# 3       1.103571    6757800
# 4       1.071429   10154200
# ...          ...        ...
# 5621  705.369995    3224300
# 5622  722.260010    3565700
# 5623  721.559998    2259800
# 5624  711.429993    2833000
# 5625  707.349976    2395600
#
# [5626 rows x 8 columns]

# %%
tesla.insert(0,'Stock_Name',"Tesla")
tesla
# Out:
#      Stock_Name        Date        Open        High         Low       Close  \
# 0         Tesla  2010-06-29    1.266667    1.666667    1.169333    1.592667
# 1         Tesla  2010-06-30    1.719333    2.028000    1.553333    1.588667
# 2         Tesla  2010-07-01    1.666667    1.728000    1.351333    1.464000
# 3         Tesla  2010-07-02    1.533333    1.540000    1.247333    1.280000
# 4         Tesla  2010-07-06    1.333333    1.333333    1.055333    1.074000
# ...         ...         ...         ...         ...         ...         ...
# 3582      Tesla  2024-09-23  242.610001  250.000000  241.919998  250.000000
# 3583      Tesla  2024-09-24  254.080002  257.190002  249.050003  254.270004
# 3584      Tesla  2024-09-25  252.539993  257.049988  252.279999  257.019989
# 3585      Tesla  2024-09-26  260.600006  261.750000  251.529999  254.220001
# 3586      Tesla  2024-09-27  257.380005  260.700012  254.119995  260.459991
#
#        Adj Close     Volume
# 0       1.592667  281494500
# 1       1.588667  257806500
# 2       1.464000  123282000
# 3       1.280000   77097000
# 4       1.074000  103003500
# ...          ...        ...
# 3582  250.000000   86927200
# 3583  254.270004   88491000
# 3584  257.019989   65034300
# 3585  254.220001   67142200
# 3586  260.459991   70988100
#
# [3587 rows x 8 columns]

# %% [markdown]
# Step 5: Converting values of columns to appropriate datatype

# %%
# Convert the datatype of Date column from object to Datetime.
amazon['Date'] = pd.to_datetime(amazon['Date'])
apple['Date'] = pd.to_datetime(apple['Date'])
meta['Date'] = pd.to_datetime(meta['Date'])
microsoft['Date'] = pd.to_datetime(microsoft['Date'])
netflix['Date'] = pd.to_datetime(netflix['Date'])
tesla['Date'] = pd.to_datetime(tesla['Date'])

# %%
# Convert the datatype of columns from object to float type.
amazon['Close in $'] = amazon['Close'].astype(float).round(4)
apple['Close in $'] = apple['Close'].astype(float).round(4)
meta['Close in $'] = meta['Close'].astype(float).round(4)
microsoft['Close in $'] = microsoft['Close'].astype(float).round(4)
netflix['Close in $'] = netflix['Close'].astype(float).round(4)
tesla['Close in $'] = tesla['Close'].astype(float).round(4)

# %%
amazon['Open in $'] = amazon['Open'].astype(float).round(4)
apple['Open in $'] = apple['Open'].astype(float).round(4)
meta['Open in $'] = meta['Open'].astype(float).round(4)
microsoft['Open in $'] = microsoft['Open'].astype(float).round(4)
netflix['Open in $'] = netflix['Open'].astype(float).round(4)
tesla['Open in $'] = tesla['Open'].astype(float).round(4)

# %%
amazon['High in $'] = amazon['High'].astype(float).round(4)
apple['High in $'] = apple['High'].astype(float).round(4)
meta['High in $'] = meta['High'].astype(float).round(4)
microsoft['High in $'] = microsoft['High'].astype(float).round(4)
netflix['High in $'] = netflix['High'].astype(float).round(4)
tesla['High in $'] = tesla['High'].astype(float).round(4)

# %%
amazon['Low in $'] = amazon['Low'].astype(float).round(4)
apple['Low in $'] = apple['Low'].astype(float).round(4)
meta['Low in $'] = meta['Low'].astype(float).round(4)
microsoft['Low in $'] = microsoft['Low'].astype(float).round(4)
netflix['Low in $'] = netflix['Low'].astype(float).round(4)
tesla['Low in $'] = tesla['Low'].astype(float).round(4)

# %%
#To prep for moving averages and rolling over function, sort date column chronically per dataset
amazon.sort_values(by=['Date'], inplace=True) 
apple.sort_values(by=['Date'], inplace=True) 
meta.sort_values(by=['Date'], inplace=True) 
microsoft.sort_values(by=['Date'], inplace=True) 
netflix.sort_values(by=['Date'], inplace=True) 
tesla.sort_values(by=['Date'], inplace=True)

# %%
# Dropping the Old Columns: Close/Last, Open, High','Low'
amazon.drop(columns = ['Close','Open','High','Low'], inplace = True)
apple.drop(columns = ['Close','Open','High','Low'], inplace = True)
meta.drop(columns = ['Close','Open','High','Low'], inplace = True)
microsoft.drop(columns = ['Close','Open','High','Low'], inplace = True)
netflix.drop(columns = ['Close','Open','High','Low'], inplace = True)
tesla.drop(columns = ['Close','Open','High','Low'], inplace = True)

# %%
# Inserting columns to each dataset where it points out the 6 month and one year moving average (in days)

# %%
amazon['MA_Six_Months'] = amazon['Close in $'].rolling(window=183).mean()
amazon['MA_One_Year'] = amazon['Close in $'].rolling(window=365).mean()
amazon
# Out:
#      Stock_Name       Date   Adj Close      Volume  Close in $  Open in $  \
# 0        Amazon 1997-05-15    0.097917  1443120000      0.0979     0.1219
# 1        Amazon 1997-05-16    0.086458   294000000      0.0865     0.0984
# 2        Amazon 1997-05-19    0.085417   122136000      0.0854     0.0880
# 3        Amazon 1997-05-20    0.081771   109344000      0.0818     0.0865
# 4        Amazon 1997-05-21    0.071354   377064000      0.0714     0.0818
# ...         ...        ...         ...         ...         ...        ...
# 6883     Amazon 2024-09-23  193.880005    36993100    193.8800   191.6400
# 6884     Amazon 2024-09-24  193.960007    43478900    193.9600   194.2700
# 6885     Amazon 2024-09-25  192.529999    26391100    192.5300   193.7500
# 6886     Amazon 2024-09-26  191.160004    36334900    191.1600   194.3100
# 6887     Amazon 2024-09-27  187.970001    36002300    187.9700   190.6800
#
#       High in $  Low in $  MA_Six_Months  MA_One_Year
# 0        0.1250    0.0964            NaN          NaN
# 1        0.0990    0.0854            NaN          NaN
# 2        0.0885    0.0812            NaN          NaN
# 3        0.0875    0.0818            NaN          NaN
# 4        0.0823    0.0688            NaN          NaN
# ...         ...       ...            ...          ...
# 6883   194.4500  190.5700     177.492131   154.034329
# 6884   195.3700  190.1300     177.732732   154.297699
# 6885   193.9500  192.1600     177.973497   154.544630
# 6886   194.5300  189.5400     178.228087   154.787507
# 6887   190.9000  187.3400     178.461585   155.021014
#
# [6888 rows x 10 columns]

# %%
apple['MA_Six_Months'] = apple['Close in $'].rolling(window=183).mean()
apple['MA_One_Year'] = apple['Close in $'].rolling(window=365).mean()
apple
# Out:
#       Stock_Name       Date   Adj Close     Volume  Close in $  Open in $  \
# 0          Apple 1980-12-12    0.098943  469033600      0.1283     0.1283
# 1          Apple 1980-12-15    0.093781  175884800      0.1217     0.1222
# 2          Apple 1980-12-16    0.086898  105728000      0.1127     0.1133
# 3          Apple 1980-12-17    0.089049   86441600      0.1155     0.1155
# 4          Apple 1980-12-18    0.091630   73449600      0.1189     0.1189
# ...          ...        ...         ...        ...         ...        ...
# 11035      Apple 2024-09-23  226.470001   54146000    226.4700   227.3400
# 11036      Apple 2024-09-24  227.369995   43556100    227.3700   228.6500
# 11037      Apple 2024-09-25  226.369995   42308700    226.3700   224.9300
# 11038      Apple 2024-09-26  227.520004   36636700    227.5200   227.3000
# 11039      Apple 2024-09-27  227.789993   34026000    227.7900   228.4600
#
#        High in $  Low in $  MA_Six_Months  MA_One_Year
# 0         0.1289    0.1283            NaN          NaN
# 1         0.1222    0.1217            NaN          NaN
# 2         0.1133    0.1127            NaN          NaN
# 3         0.1161    0.1155            NaN          NaN
# 4         0.1194    0.1189            NaN          NaN
# ...          ...       ...            ...          ...
# 11035   229.4500  225.8100     196.669727   189.031753
# 11036   229.3500  225.7300     196.897760   189.216055
# 11037   227.2900  224.0200     197.127923   189.382658
# 11038   228.5000  225.4100     197.377158   189.553370
# 11039   229.5200  227.3000     197.631858   189.724767
#
# [11040 rows x 10 columns]

# %%
meta['MA_Six_Months'] = meta['Close in $'].rolling(window=183).mean()
meta['MA_One_Year'] = meta['Close in $'].rolling(window=365).mean()
meta
# Out:
#      Stock_Name       Date   Adj Close     Volume  Close in $  Open in $  \
# 0          Meta 2012-05-18   38.115242  573576400       38.23      42.05
# 1          Meta 2012-05-21   33.927845  168192700       34.03      36.53
# 2          Meta 2012-05-22   30.906942  101786600       31.00      32.61
# 3          Meta 2012-05-23   31.903940   73600000       32.00      31.37
# 4          Meta 2012-05-24   32.930847   50237200       33.03      32.95
# ...         ...        ...         ...        ...         ...        ...
# 3105       Meta 2024-09-23  564.409973   12830700      564.41     569.50
# 3106       Meta 2024-09-24  563.330017   12993000      563.33     566.68
# 3107       Meta 2024-09-25  568.309998   16543400      568.31     564.05
# 3108       Meta 2024-09-26  567.840027   14400800      567.84     575.73
# 3109       Meta 2024-09-27  567.359985    9398400      567.36     570.10
#
#       High in $  Low in $  MA_Six_Months  MA_One_Year
# 0         45.00     38.00            NaN          NaN
# 1         36.66     33.00            NaN          NaN
# 2         33.59     30.94            NaN          NaN
# 3         32.50     31.36            NaN          NaN
# 4         33.21     31.77            NaN          NaN
# ...         ...       ...            ...          ...
# 3105     573.98    562.41     480.470984   387.505452
# 3106     567.75    554.19     481.656995   388.462521
# 3107     576.88    563.72     482.880164   389.415836
# 3108     577.40    562.35     484.086284   390.364740
# 3109     570.84    564.51     485.263388   391.319534
#
# [3110 rows x 10 columns]

# %%
microsoft['MA_Six_Months'] = microsoft['Close in $'].rolling(window=183).mean()
microsoft['MA_One_Year'] = microsoft['Close in $'].rolling(window=365).mean()
microsoft
# Out:
#      Stock_Name       Date   Adj Close      Volume  Close in $  Open in $  \
# 0     Microsoft 1986-03-13    0.059947  1031788800      0.0972     0.0885
# 1     Microsoft 1986-03-14    0.062087   308160000      0.1007     0.0972
# 2     Microsoft 1986-03-17    0.063158   133171200      0.1024     0.1007
# 3     Microsoft 1986-03-18    0.061552    67766400      0.0998     0.1024
# 4     Microsoft 1986-03-19    0.060482    47894400      0.0981     0.0998
# ...         ...        ...         ...         ...         ...        ...
# 9709  Microsoft 2024-09-23  433.510010    15128900    433.5100   434.2800
# 9710  Microsoft 2024-09-24  429.170013    17015800    429.1700   433.0000
# 9711  Microsoft 2024-09-25  432.109985    13396400    432.1100   429.8300
# 9712  Microsoft 2024-09-26  431.309998    14492000    431.3100   435.0900
# 9713  Microsoft 2024-09-27  428.019989    14896100    428.0200   431.5200
#
#       High in $  Low in $  MA_Six_Months  MA_One_Year
# 0        0.1016    0.0885            NaN          NaN
# 1        0.1024    0.0972            NaN          NaN
# 2        0.1033    0.1007            NaN          NaN
# 3        0.1033    0.0990            NaN          NaN
# 4        0.1007    0.0972            NaN          NaN
# ...         ...       ...            ...          ...
# 9709   436.4600  430.3900     418.071803   376.595534
# 9710   433.3500  426.1000     418.390383   376.994658
# 9711   433.1200  428.5700     418.726503   377.384438
# 9712   435.3000  429.1300     419.072787   377.782164
# 9713   431.8500  427.4700     419.402131   378.163589
#
# [9714 rows x 10 columns]

# %%
netflix['MA_Six_Months'] = netflix['Close in $'].rolling(window=183).mean()
netflix['MA_One_Year'] = netflix['Close in $'].rolling(window=365).mean()
netflix
# Out:
#      Stock_Name       Date   Adj Close     Volume  Close in $  Open in $  \
# 0       Netflix 2002-05-23    1.196429  104790000      1.1964     1.1564
# 1       Netflix 2002-05-24    1.210000   11104800      1.2100     1.2143
# 2       Netflix 2002-05-28    1.157143    6609400      1.1571     1.2136
# 3       Netflix 2002-05-29    1.103571    6757800      1.1036     1.1643
# 4       Netflix 2002-05-30    1.071429   10154200      1.0714     1.1079
# ...         ...        ...         ...        ...         ...        ...
# 5621    Netflix 2024-09-23  705.369995    3224300    705.3700   702.3900
# 5622    Netflix 2024-09-24  722.260010    3565700    722.2600   706.6300
# 5623    Netflix 2024-09-25  721.559998    2259800    721.5600   721.0000
# 5624    Netflix 2024-09-26  711.429993    2833000    711.4300   724.7300
# 5625    Netflix 2024-09-27  707.349976    2395600    707.3500   708.3600
#
#       High in $  Low in $  MA_Six_Months  MA_One_Year
# 0        1.2429    1.1457            NaN          NaN
# 1        1.2250    1.1971            NaN          NaN
# 2        1.2321    1.1571            NaN          NaN
# 3        1.1643    1.0857            NaN          NaN
# 4        1.1079    1.0714            NaN          NaN
# ...         ...       ...            ...          ...
# 5621   712.2500  699.1600     617.318962   514.957589
# 5622   722.4400  704.4500     618.705628   516.029452
# 5623   725.1200  716.2100     620.078852   517.057863
# 5624   725.2600  701.7200     621.372623   518.079233
# 5625   710.7100  701.2500     622.647432   519.105616
#
# [5626 rows x 10 columns]

# %%
tesla['MA_Six_Months'] = tesla['Close in $'].rolling(window=183).mean()
tesla['MA_One_Year'] = tesla['Close in $'].rolling(window=365).mean()
tesla
# Out:
#      Stock_Name       Date   Adj Close     Volume  Close in $  Open in $  \
# 0         Tesla 2010-06-29    1.592667  281494500      1.5927     1.2667
# 1         Tesla 2010-06-30    1.588667  257806500      1.5887     1.7193
# 2         Tesla 2010-07-01    1.464000  123282000      1.4640     1.6667
# 3         Tesla 2010-07-02    1.280000   77097000      1.2800     1.5333
# 4         Tesla 2010-07-06    1.074000  103003500      1.0740     1.3333
# ...         ...        ...         ...        ...         ...        ...
# 3582      Tesla 2024-09-23  250.000000   86927200    250.0000   242.6100
# 3583      Tesla 2024-09-24  254.270004   88491000    254.2700   254.0800
# 3584      Tesla 2024-09-25  257.019989   65034300    257.0200   252.5400
# 3585      Tesla 2024-09-26  254.220001   67142200    254.2200   260.6000
# 3586      Tesla 2024-09-27  260.459991   70988100    260.4600   257.3800
#
#       High in $  Low in $  MA_Six_Months  MA_One_Year
# 0        1.6667    1.1693            NaN          NaN
# 1        2.0280    1.5533            NaN          NaN
# 2        1.7280    1.3513            NaN          NaN
# 3        1.5400    1.2473            NaN          NaN
# 4        1.3333    1.0553            NaN          NaN
# ...         ...       ...            ...          ...
# 3582   250.0000  241.9200     198.010055   215.506164
# 3583   257.1900  249.0500     198.042022   215.708164
# 3584   257.0500  252.2800     198.143497   215.903014
# 3585   261.7500  251.5300     198.232514   216.092658
# 3586   260.7000  254.1200     198.358033   216.293808
#
# [3587 rows x 10 columns]

# %% [markdown]
# Step 6: Checking For Duplicates

# %%
amazon[amazon.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Stock_Name, Date, Adj Close, Volume, Close in $, Open in $, High in $, Low in $, MA_Six_Months, MA_One_Year]
# Index: []

# %%
apple[apple.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Stock_Name, Date, Adj Close, Volume, Close in $, Open in $, High in $, Low in $, MA_Six_Months, MA_One_Year]
# Index: []

# %%
meta[meta.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Stock_Name, Date, Adj Close, Volume, Close in $, Open in $, High in $, Low in $, MA_Six_Months, MA_One_Year]
# Index: []

# %%
microsoft[microsoft.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Stock_Name, Date, Adj Close, Volume, Close in $, Open in $, High in $, Low in $, MA_Six_Months, MA_One_Year]
# Index: []

# %%
netflix[netflix.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Stock_Name, Date, Adj Close, Volume, Close in $, Open in $, High in $, Low in $, MA_Six_Months, MA_One_Year]
# Index: []

# %%
tesla[tesla.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Stock_Name, Date, Adj Close, Volume, Close in $, Open in $, High in $, Low in $, MA_Six_Months, MA_One_Year]
# Index: []

# %% [markdown]
# Step 7: Combine All Datasets

# %%
frames_stocks = [amazon,apple,meta,microsoft,netflix,tesla]

stocks = pd.concat(frames_stocks, axis = 0)
stocks
# Out:
#      Stock_Name       Date   Adj Close      Volume  Close in $  Open in $  \
# 0        Amazon 1997-05-15    0.097917  1443120000      0.0979     0.1219
# 1        Amazon 1997-05-16    0.086458   294000000      0.0865     0.0984
# 2        Amazon 1997-05-19    0.085417   122136000      0.0854     0.0880
# 3        Amazon 1997-05-20    0.081771   109344000      0.0818     0.0865
# 4        Amazon 1997-05-21    0.071354   377064000      0.0714     0.0818
# ...         ...        ...         ...         ...         ...        ...
# 3582      Tesla 2024-09-23  250.000000    86927200    250.0000   242.6100
# 3583      Tesla 2024-09-24  254.270004    88491000    254.2700   254.0800
# 3584      Tesla 2024-09-25  257.019989    65034300    257.0200   252.5400
# 3585      Tesla 2024-09-26  254.220001    67142200    254.2200   260.6000
# 3586      Tesla 2024-09-27  260.459991    70988100    260.4600   257.3800
#
#       High in $  Low in $  MA_Six_Months  MA_One_Year
# 0        0.1250    0.0964            NaN          NaN
# 1        0.0990    0.0854            NaN          NaN
# 2        0.0885    0.0812            NaN          NaN
# 3        0.0875    0.0818            NaN          NaN
# 4        0.0823    0.0688            NaN          NaN
# ...         ...       ...            ...          ...
# 3582   250.0000  241.9200     198.010055   215.506164
# 3583   257.1900  249.0500     198.042022   215.708164
# 3584   257.0500  252.2800     198.143497   215.903014
# 3585   261.7500  251.5300     198.232514   216.092658
# 3586   260.7000  254.1200     198.358033   216.293808
#
# [39965 rows x 10 columns]

# %%
stocks.dtypes
# Out:
# Stock_Name               object
# Date             datetime64[ns]
# Adj Close               float64
# Volume                    int64
# Close in $              float64
# Open in $               float64
# High in $               float64
# Low in $                float64
# MA_Six_Months           float64
# MA_One_Year             float64
# dtype: object

# %%
# Reordering Columns
stocks = stocks[['Date','Stock_Name','Volume','Close in $','Open in $','High in $','Low in $', 'MA_Six_Months', 'MA_One_Year']]
stocks
# Out:
#            Date Stock_Name      Volume  Close in $  Open in $  High in $  \
# 0    1997-05-15     Amazon  1443120000      0.0979     0.1219     0.1250
# 1    1997-05-16     Amazon   294000000      0.0865     0.0984     0.0990
# 2    1997-05-19     Amazon   122136000      0.0854     0.0880     0.0885
# 3    1997-05-20     Amazon   109344000      0.0818     0.0865     0.0875
# 4    1997-05-21     Amazon   377064000      0.0714     0.0818     0.0823
# ...         ...        ...         ...         ...        ...        ...
# 3582 2024-09-23      Tesla    86927200    250.0000   242.6100   250.0000
# 3583 2024-09-24      Tesla    88491000    254.2700   254.0800   257.1900
# 3584 2024-09-25      Tesla    65034300    257.0200   252.5400   257.0500
# 3585 2024-09-26      Tesla    67142200    254.2200   260.6000   261.7500
# 3586 2024-09-27      Tesla    70988100    260.4600   257.3800   260.7000
#
#       Low in $  MA_Six_Months  MA_One_Year
# 0       0.0964            NaN          NaN
# 1       0.0854            NaN          NaN
# 2       0.0812            NaN          NaN
# 3       0.0818            NaN          NaN
# 4       0.0688            NaN          NaN
# ...        ...            ...          ...
# 3582  241.9200     198.010055   215.506164
# 3583  249.0500     198.042022   215.708164
# 3584  252.2800     198.143497   215.903014
# 3585  251.5300     198.232514   216.092658
# 3586  254.1200     198.358033   216.293808
#
# [39965 rows x 9 columns]

# %% [markdown]
# Step 8: Exporting drafted dataframe

# %%
# Exporting drafted dataframe
stocks.to_csv(os.path.join(path, 'New Files', '6_Stocks_Transformed.csv'))
