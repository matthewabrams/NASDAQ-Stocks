# %% [markdown]
# Step 1: Importing Python Libraries

# %%
# Importing libraries

import pandas as pd
import numpy as np
import os
from datetime import datetime

# %% [markdown]
# Step 2: Importing Stock Datasets

# %%
# Importing Amazon stock data

path = r'/Users/matthewabrams/Desktop/Stocks Data/Stock Datasets/'
amazon = pd.read_csv(os.path.join(path, 'Original Stock Data/HistoricalData_Amazon.csv'), index_col = False)
amazon
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...          ...         ...         ...         ...         ...         ...
# 6917  2024-11-08  209.720001  209.960007  207.440002  208.179993  208.179993
# 6918  2024-11-11  208.500000  209.649994  205.589996  206.839996  206.839996
# 6919  2024-11-12  208.369995  209.539993  206.009995  208.910004  208.910004
# 6920  2024-11-13  209.399994  215.089996  209.139999  214.100006  214.100006
# 6921  2024-11-14  214.160004  215.899994  210.880005  211.479996  211.479996
#
#           Volume
# 0     1443120000
# 1      294000000
# 2      122136000
# 3      109344000
# 4      377064000
# ...          ...
# 6917    36075800
# 6918    35456000
# 6919    38942900
# 6920    46212900
# 6921    42620300
#
# [6922 rows x 7 columns]

# %%
# Importing Apple stock data

apple = pd.read_csv(os.path.join(path, 'Original Stock Data/HistoricalData_Apple.csv'), index_col = False)
apple
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098834
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093678
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086802
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.088951
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091530
# ...           ...         ...         ...         ...         ...         ...
# 11069  2024-11-08  227.169998  228.660004  226.410004  226.960007  226.960007
# 11070  2024-11-11  225.000000  225.699997  221.500000  224.229996  224.229996
# 11071  2024-11-12  224.550003  225.589996  223.360001  224.229996  224.229996
# 11072  2024-11-13  224.009995  226.649994  222.759995  225.119995  225.119995
# 11073  2024-11-14  225.020004  228.869995  225.000000  228.220001  228.220001
#
#           Volume
# 0      469033600
# 1      175884800
# 2      105728000
# 3       86441600
# 4       73449600
# ...          ...
# 11069   38328800
# 11070   42005600
# 11071   40398300
# 11072   48566200
# 11073   44923900
#
# [11074 rows x 7 columns]

# %%
# Importing Meta stock data

meta = pd.read_csv(os.path.join(path, 'Original Stock Data/HistoricalData_Meta.csv'), index_col = False)
meta
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-05-18   42.049999   45.000000   38.000000   38.230000   38.115242
# 1     2012-05-21   36.529999   36.660000   33.000000   34.029999   33.927845
# 2     2012-05-22   32.610001   33.590000   30.940001   31.000000   30.906942
# 3     2012-05-23   31.370001   32.500000   31.360001   32.000000   31.903942
# 4     2012-05-24   32.950001   33.209999   31.770000   33.029999   32.930851
# ...          ...         ...         ...         ...         ...         ...
# 3139  2024-11-08  591.539978  593.099976  584.520020  589.340027  589.340027
# 3140  2024-11-11  586.359985  587.000000  576.510010  583.169983  583.169983
# 3141  2024-11-12  588.539978  599.659973  580.380005  584.820007  584.820007
# 3142  2024-11-13  582.609985  585.640015  575.169983  580.000000  580.000000
# 3143  2024-11-14  577.000000  580.760010  573.010010  577.159973  577.159973
#
#          Volume
# 0     573576400
# 1     168192700
# 2     101786600
# 3      73600000
# 4      50237200
# ...         ...
# 3139    9415700
# 3140   10209100
# 3141   16287700
# 3142   10757600
# 3143   11053700
#
# [3144 rows x 7 columns]

# %%
# Importing Microsoft stock data

microsoft = pd.read_csv(os.path.join(path, 'Original Stock Data/HistoricalData_Microsoft.csv'), index_col = False)
microsoft
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.059947
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062087
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063158
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.061552
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060482
# ...          ...         ...         ...         ...         ...         ...
# 9743  2024-11-08  425.320007  426.500000  421.779999  422.540009  422.540009
# 9744  2024-11-11  422.519989  424.809998  416.000000  418.010010  418.010010
# 9745  2024-11-12  418.250000  424.440002  417.200012  423.029999  423.029999
# 9746  2024-11-13  421.640015  429.329987  418.209991  425.200012  425.200012
# 9747  2024-11-14  425.000000  428.170013  420.000000  426.890015  426.890015
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9743    16891400
# 9744    24503300
# 9745    19401200
# 9746    21502200
# 9747    30246900
#
# [9748 rows x 7 columns]

# %%
# Importing Netflix stock data

netflix = pd.read_csv(os.path.join(path, 'Original Stock Data/HistoricalData_Netflix.csv'), index_col = False)
netflix
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 1     2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2     2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 3     2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 4     2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...          ...         ...         ...         ...         ...         ...
# 5655  2024-11-08  797.359985  799.059998  788.650024  795.039978  795.039978
# 5656  2024-11-11  795.900024  806.820007  795.570007  805.440002  805.440002
# 5657  2024-11-12  807.500000  820.369995  803.750000  819.500000  819.500000
# 5658  2024-11-13  822.619995  836.989990  820.539978  830.469971  830.469971
# 5659  2024-11-14  833.669983  841.000000  830.020020  837.260010  837.260010
#
#          Volume
# 0     104790000
# 1      11104800
# 2       6609400
# 3       6757800
# 4      10154200
# ...         ...
# 5655    1910600
# 5656    2399200
# 5657    2814100
# 5658    2767800
# 5659    3038200
#
# [5660 rows x 7 columns]

# %%
# Importing Telsa stock data

tesla = pd.read_csv(os.path.join(path, 'Original Stock Data/HistoricalData_Tesla.csv'), index_col = False)
tesla
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1     2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2     2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3     2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4     2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...          ...         ...         ...         ...         ...         ...
# 3616  2024-11-08  299.140015  328.709991  297.660004  321.220001  321.220001
# 3617  2024-11-11  346.299988  358.640015  336.000000  350.000000  350.000000
# 3618  2024-11-12  342.739990  345.839996  323.309998  328.489990  328.489990
# 3619  2024-11-13  335.850006  344.600006  322.500000  330.239990  330.239990
# 3620  2024-11-14  327.690002  329.980011  310.369995  311.179993  311.179993
#
#          Volume
# 0     281494500
# 1     257806500
# 2     123282000
# 3      77097000
# 4     103003500
# ...         ...
# 3616  204782800
# 3617  210521600
# 3618  155726000
# 3619  125405600
# 3620  120726100
#
# [3621 rows x 7 columns]

# %% [markdown]
# Step 3: Observing Datatypes for all datasets

# %%
amazon.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
apple.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
meta.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
microsoft.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
netflix.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
tesla.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# Step 4: Checking for missing values

# %%
amazon.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
apple.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
meta.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
microsoft.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
netflix.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
tesla.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# Step 4: Adding Additional Columns to Each Dataset

# %%
# Inserting column to each dataset where it points out the stock name
amazon.insert(0,'Stock_Name',"Amazon")
amazon
# Out:
#      Stock_Name        Date        Open        High         Low       Close  \
# 0        Amazon  1997-05-15    0.121875    0.125000    0.096354    0.097917
# 1        Amazon  1997-05-16    0.098438    0.098958    0.085417    0.086458
# 2        Amazon  1997-05-19    0.088021    0.088542    0.081250    0.085417
# 3        Amazon  1997-05-20    0.086458    0.087500    0.081771    0.081771
# 4        Amazon  1997-05-21    0.081771    0.082292    0.068750    0.071354
# ...         ...         ...         ...         ...         ...         ...
# 6917     Amazon  2024-11-08  209.720001  209.960007  207.440002  208.179993
# 6918     Amazon  2024-11-11  208.500000  209.649994  205.589996  206.839996
# 6919     Amazon  2024-11-12  208.369995  209.539993  206.009995  208.910004
# 6920     Amazon  2024-11-13  209.399994  215.089996  209.139999  214.100006
# 6921     Amazon  2024-11-14  214.160004  215.899994  210.880005  211.479996
#
#        Adj Close      Volume
# 0       0.097917  1443120000
# 1       0.086458   294000000
# 2       0.085417   122136000
# 3       0.081771   109344000
# 4       0.071354   377064000
# ...          ...         ...
# 6917  208.179993    36075800
# 6918  206.839996    35456000
# 6919  208.910004    38942900
# 6920  214.100006    46212900
# 6921  211.479996    42620300
#
# [6922 rows x 8 columns]

# %%
apple.insert(0,'Stock_Name',"Apple")
apple
# Out:
#       Stock_Name        Date        Open        High         Low       Close  \
# 0          Apple  1980-12-12    0.128348    0.128906    0.128348    0.128348
# 1          Apple  1980-12-15    0.122210    0.122210    0.121652    0.121652
# 2          Apple  1980-12-16    0.113281    0.113281    0.112723    0.112723
# 3          Apple  1980-12-17    0.115513    0.116071    0.115513    0.115513
# 4          Apple  1980-12-18    0.118862    0.119420    0.118862    0.118862
# ...          ...         ...         ...         ...         ...         ...
# 11069      Apple  2024-11-08  227.169998  228.660004  226.410004  226.960007
# 11070      Apple  2024-11-11  225.000000  225.699997  221.500000  224.229996
# 11071      Apple  2024-11-12  224.550003  225.589996  223.360001  224.229996
# 11072      Apple  2024-11-13  224.009995  226.649994  222.759995  225.119995
# 11073      Apple  2024-11-14  225.020004  228.869995  225.000000  228.220001
#
#         Adj Close     Volume
# 0        0.098834  469033600
# 1        0.093678  175884800
# 2        0.086802  105728000
# 3        0.088951   86441600
# 4        0.091530   73449600
# ...           ...        ...
# 11069  226.960007   38328800
# 11070  224.229996   42005600
# 11071  224.229996   40398300
# 11072  225.119995   48566200
# 11073  228.220001   44923900
#
# [11074 rows x 8 columns]

# %%
meta.insert(0,'Stock_Name',"Meta")
meta
# Out:
#      Stock_Name        Date        Open        High         Low       Close  \
# 0          Meta  2012-05-18   42.049999   45.000000   38.000000   38.230000
# 1          Meta  2012-05-21   36.529999   36.660000   33.000000   34.029999
# 2          Meta  2012-05-22   32.610001   33.590000   30.940001   31.000000
# 3          Meta  2012-05-23   31.370001   32.500000   31.360001   32.000000
# 4          Meta  2012-05-24   32.950001   33.209999   31.770000   33.029999
# ...         ...         ...         ...         ...         ...         ...
# 3139       Meta  2024-11-08  591.539978  593.099976  584.520020  589.340027
# 3140       Meta  2024-11-11  586.359985  587.000000  576.510010  583.169983
# 3141       Meta  2024-11-12  588.539978  599.659973  580.380005  584.820007
# 3142       Meta  2024-11-13  582.609985  585.640015  575.169983  580.000000
# 3143       Meta  2024-11-14  577.000000  580.760010  573.010010  577.159973
#
#        Adj Close     Volume
# 0      38.115242  573576400
# 1      33.927845  168192700
# 2      30.906942  101786600
# 3      31.903942   73600000
# 4      32.930851   50237200
# ...          ...        ...
# 3139  589.340027    9415700
# 3140  583.169983   10209100
# 3141  584.820007   16287700
# 3142  580.000000   10757600
# 3143  577.159973   11053700
#
# [3144 rows x 8 columns]

# %%
microsoft.insert(0,'Stock_Name',"Microsoft")
microsoft
# Out:
#      Stock_Name        Date        Open        High         Low       Close  \
# 0     Microsoft  1986-03-13    0.088542    0.101563    0.088542    0.097222
# 1     Microsoft  1986-03-14    0.097222    0.102431    0.097222    0.100694
# 2     Microsoft  1986-03-17    0.100694    0.103299    0.100694    0.102431
# 3     Microsoft  1986-03-18    0.102431    0.103299    0.098958    0.099826
# 4     Microsoft  1986-03-19    0.099826    0.100694    0.097222    0.098090
# ...         ...         ...         ...         ...         ...         ...
# 9743  Microsoft  2024-11-08  425.320007  426.500000  421.779999  422.540009
# 9744  Microsoft  2024-11-11  422.519989  424.809998  416.000000  418.010010
# 9745  Microsoft  2024-11-12  418.250000  424.440002  417.200012  423.029999
# 9746  Microsoft  2024-11-13  421.640015  429.329987  418.209991  425.200012
# 9747  Microsoft  2024-11-14  425.000000  428.170013  420.000000  426.890015
#
#        Adj Close      Volume
# 0       0.059947  1031788800
# 1       0.062087   308160000
# 2       0.063158   133171200
# 3       0.061552    67766400
# 4       0.060482    47894400
# ...          ...         ...
# 9743  422.540009    16891400
# 9744  418.010010    24503300
# 9745  423.029999    19401200
# 9746  425.200012    21502200
# 9747  426.890015    30246900
#
# [9748 rows x 8 columns]

# %%
netflix.insert(0,'Stock_Name',"Netflix")
netflix
# Out:
#      Stock_Name        Date        Open        High         Low       Close  \
# 0       Netflix  2002-05-23    1.156429    1.242857    1.145714    1.196429
# 1       Netflix  2002-05-24    1.214286    1.225000    1.197143    1.210000
# 2       Netflix  2002-05-28    1.213571    1.232143    1.157143    1.157143
# 3       Netflix  2002-05-29    1.164286    1.164286    1.085714    1.103571
# 4       Netflix  2002-05-30    1.107857    1.107857    1.071429    1.071429
# ...         ...         ...         ...         ...         ...         ...
# 5655    Netflix  2024-11-08  797.359985  799.059998  788.650024  795.039978
# 5656    Netflix  2024-11-11  795.900024  806.820007  795.570007  805.440002
# 5657    Netflix  2024-11-12  807.500000  820.369995  803.750000  819.500000
# 5658    Netflix  2024-11-13  822.619995  836.989990  820.539978  830.469971
# 5659    Netflix  2024-11-14  833.669983  841.000000  830.020020  837.260010
#
#        Adj Close     Volume
# 0       1.196429  104790000
# 1       1.210000   11104800
# 2       1.157143    6609400
# 3       1.103571    6757800
# 4       1.071429   10154200
# ...          ...        ...
# 5655  795.039978    1910600
# 5656  805.440002    2399200
# 5657  819.500000    2814100
# 5658  830.469971    2767800
# 5659  837.260010    3038200
#
# [5660 rows x 8 columns]

# %%
tesla.insert(0,'Stock_Name',"Tesla")
tesla
# Out:
#      Stock_Name        Date        Open        High         Low       Close  \
# 0         Tesla  2010-06-29    1.266667    1.666667    1.169333    1.592667
# 1         Tesla  2010-06-30    1.719333    2.028000    1.553333    1.588667
# 2         Tesla  2010-07-01    1.666667    1.728000    1.351333    1.464000
# 3         Tesla  2010-07-02    1.533333    1.540000    1.247333    1.280000
# 4         Tesla  2010-07-06    1.333333    1.333333    1.055333    1.074000
# ...         ...         ...         ...         ...         ...         ...
# 3616      Tesla  2024-11-08  299.140015  328.709991  297.660004  321.220001
# 3617      Tesla  2024-11-11  346.299988  358.640015  336.000000  350.000000
# 3618      Tesla  2024-11-12  342.739990  345.839996  323.309998  328.489990
# 3619      Tesla  2024-11-13  335.850006  344.600006  322.500000  330.239990
# 3620      Tesla  2024-11-14  327.690002  329.980011  310.369995  311.179993
#
#        Adj Close     Volume
# 0       1.592667  281494500
# 1       1.588667  257806500
# 2       1.464000  123282000
# 3       1.280000   77097000
# 4       1.074000  103003500
# ...          ...        ...
# 3616  321.220001  204782800
# 3617  350.000000  210521600
# 3618  328.489990  155726000
# 3619  330.239990  125405600
# 3620  311.179993  120726100
#
# [3621 rows x 8 columns]

# %% [markdown]
# Step 5: Converting values of columns to appropriate datatype

# %%
# Convert the datatype of Date column from object to Datetime.
amazon['Date'] = pd.to_datetime(amazon['Date'])
apple['Date'] = pd.to_datetime(apple['Date'])
meta['Date'] = pd.to_datetime(meta['Date'])
microsoft['Date'] = pd.to_datetime(microsoft['Date'])
netflix['Date'] = pd.to_datetime(netflix['Date'])
tesla['Date'] = pd.to_datetime(tesla['Date'])

# %%
# Convert the datatype of columns from object to float type.
amazon['Close in $'] = amazon['Close'].astype(float).round(4)
apple['Close in $'] = apple['Close'].astype(float).round(4)
meta['Close in $'] = meta['Close'].astype(float).round(4)
microsoft['Close in $'] = microsoft['Close'].astype(float).round(4)
netflix['Close in $'] = netflix['Close'].astype(float).round(4)
tesla['Close in $'] = tesla['Close'].astype(float).round(4)

# %%
amazon['Open in $'] = amazon['Open'].astype(float).round(4)
apple['Open in $'] = apple['Open'].astype(float).round(4)
meta['Open in $'] = meta['Open'].astype(float).round(4)
microsoft['Open in $'] = microsoft['Open'].astype(float).round(4)
netflix['Open in $'] = netflix['Open'].astype(float).round(4)
tesla['Open in $'] = tesla['Open'].astype(float).round(4)

# %%
amazon['High in $'] = amazon['High'].astype(float).round(4)
apple['High in $'] = apple['High'].astype(float).round(4)
meta['High in $'] = meta['High'].astype(float).round(4)
microsoft['High in $'] = microsoft['High'].astype(float).round(4)
netflix['High in $'] = netflix['High'].astype(float).round(4)
tesla['High in $'] = tesla['High'].astype(float).round(4)

# %%
amazon['Low in $'] = amazon['Low'].astype(float).round(4)
apple['Low in $'] = apple['Low'].astype(float).round(4)
meta['Low in $'] = meta['Low'].astype(float).round(4)
microsoft['Low in $'] = microsoft['Low'].astype(float).round(4)
netflix['Low in $'] = netflix['Low'].astype(float).round(4)
tesla['Low in $'] = tesla['Low'].astype(float).round(4)

# %%
#To prep for moving averages and rolling over function, sort date column chronically per dataset
amazon.sort_values(by=['Date'], inplace=True) 
apple.sort_values(by=['Date'], inplace=True) 
meta.sort_values(by=['Date'], inplace=True) 
microsoft.sort_values(by=['Date'], inplace=True) 
netflix.sort_values(by=['Date'], inplace=True) 
tesla.sort_values(by=['Date'], inplace=True)

# %%
# Dropping the Old Columns: Close/Last, Open, High','Low'
amazon.drop(columns = ['Close','Open','High','Low'], inplace = True)
apple.drop(columns = ['Close','Open','High','Low'], inplace = True)
meta.drop(columns = ['Close','Open','High','Low'], inplace = True)
microsoft.drop(columns = ['Close','Open','High','Low'], inplace = True)
netflix.drop(columns = ['Close','Open','High','Low'], inplace = True)
tesla.drop(columns = ['Close','Open','High','Low'], inplace = True)

# %%
# Inserting columns to each dataset where it points out the 6 month and one year moving average (in days)

# %%
amazon['MA_Six_Months'] = amazon['Close in $'].rolling(window=183).mean()
amazon['MA_One_Year'] = amazon['Close in $'].rolling(window=365).mean()
amazon
# Out:
#      Stock_Name       Date   Adj Close      Volume  Close in $  Open in $  \
# 0        Amazon 1997-05-15    0.097917  1443120000      0.0979     0.1219
# 1        Amazon 1997-05-16    0.086458   294000000      0.0865     0.0984
# 2        Amazon 1997-05-19    0.085417   122136000      0.0854     0.0880
# 3        Amazon 1997-05-20    0.081771   109344000      0.0818     0.0865
# 4        Amazon 1997-05-21    0.071354   377064000      0.0714     0.0818
# ...         ...        ...         ...         ...         ...        ...
# 6917     Amazon 2024-11-08  208.179993    36075800    208.1800   209.7200
# 6918     Amazon 2024-11-11  206.839996    35456000    206.8400   208.5000
# 6919     Amazon 2024-11-12  208.910004    38942900    208.9100   208.3700
# 6920     Amazon 2024-11-13  214.100006    46212900    214.1000   209.4000
# 6921     Amazon 2024-11-14  211.479996    42620300    211.4800   214.1600
#
#       High in $  Low in $  MA_Six_Months  MA_One_Year
# 0        0.1250    0.0964            NaN          NaN
# 1        0.0990    0.0854            NaN          NaN
# 2        0.0885    0.0812            NaN          NaN
# 3        0.0875    0.0818            NaN          NaN
# 4        0.0823    0.0688            NaN          NaN
# ...         ...       ...            ...          ...
# 6917   209.9600  207.4400     183.164481   161.633534
# 6918   209.6500  205.5900     183.373497   161.869863
# 6919   209.5400  206.0100     183.561093   162.105863
# 6920   215.0900  209.1400     183.774809   162.352027
# 6921   215.9000  210.8800     183.975628   162.588137
#
# [6922 rows x 10 columns]

# %%
apple['MA_Six_Months'] = apple['Close in $'].rolling(window=183).mean()
apple['MA_One_Year'] = apple['Close in $'].rolling(window=365).mean()
apple
# Out:
#       Stock_Name       Date   Adj Close     Volume  Close in $  Open in $  \
# 0          Apple 1980-12-12    0.098834  469033600      0.1283     0.1283
# 1          Apple 1980-12-15    0.093678  175884800      0.1217     0.1222
# 2          Apple 1980-12-16    0.086802  105728000      0.1127     0.1133
# 3          Apple 1980-12-17    0.088951   86441600      0.1155     0.1155
# 4          Apple 1980-12-18    0.091530   73449600      0.1189     0.1189
# ...          ...        ...         ...        ...         ...        ...
# 11069      Apple 2024-11-08  226.960007   38328800    226.9600   227.1700
# 11070      Apple 2024-11-11  224.229996   42005600    224.2300   225.0000
# 11071      Apple 2024-11-12  224.229996   40398300    224.2300   224.5500
# 11072      Apple 2024-11-13  225.119995   48566200    225.1200   224.0100
# 11073      Apple 2024-11-14  228.220001   44923900    228.2200   225.0200
#
#        High in $  Low in $  MA_Six_Months  MA_One_Year
# 0         0.1289    0.1283            NaN          NaN
# 1         0.1222    0.1217            NaN          NaN
# 2         0.1133    0.1127            NaN          NaN
# 3         0.1161    0.1155            NaN          NaN
# 4         0.1194    0.1189            NaN          NaN
# ...          ...       ...            ...          ...
# 11069   228.6600  226.4100     204.409180   194.526548
# 11070   225.7000  221.5000     204.638197   194.655260
# 11071   225.5900  223.3600     204.856011   194.776192
# 11072   226.6500  222.7600     205.088798   194.897205
# 11073   228.8700  225.0000     205.345956   195.030466
#
# [11074 rows x 10 columns]

# %%
meta['MA_Six_Months'] = meta['Close in $'].rolling(window=183).mean()
meta['MA_One_Year'] = meta['Close in $'].rolling(window=365).mean()
meta
# Out:
#      Stock_Name       Date   Adj Close     Volume  Close in $  Open in $  \
# 0          Meta 2012-05-18   38.115242  573576400       38.23      42.05
# 1          Meta 2012-05-21   33.927845  168192700       34.03      36.53
# 2          Meta 2012-05-22   30.906942  101786600       31.00      32.61
# 3          Meta 2012-05-23   31.903942   73600000       32.00      31.37
# 4          Meta 2012-05-24   32.930851   50237200       33.03      32.95
# ...         ...        ...         ...        ...         ...        ...
# 3139       Meta 2024-11-08  589.340027    9415700      589.34     591.54
# 3140       Meta 2024-11-11  583.169983   10209100      583.17     586.36
# 3141       Meta 2024-11-12  584.820007   16287700      584.82     588.54
# 3142       Meta 2024-11-13  580.000000   10757600      580.00     582.61
# 3143       Meta 2024-11-14  577.159973   11053700      577.16     577.00
#
#       High in $  Low in $  MA_Six_Months  MA_One_Year
# 0         45.00     38.00            NaN          NaN
# 1         36.66     33.00            NaN          NaN
# 2         33.59     30.94            NaN          NaN
# 3         32.50     31.36            NaN          NaN
# 4         33.21     31.77            NaN          NaN
# ...         ...       ...            ...          ...
# 3139     593.10    584.52     512.093934   419.642603
# 3140     587.00    576.51     512.723115   420.515068
# 3141     599.66    580.38     513.262404   421.370438
# 3142     585.64    575.17     513.786831   422.212603
# 3143     580.76    573.01     514.308251   423.050329
#
# [3144 rows x 10 columns]

# %%
microsoft['MA_Six_Months'] = microsoft['Close in $'].rolling(window=183).mean()
microsoft['MA_One_Year'] = microsoft['Close in $'].rolling(window=365).mean()
microsoft
# Out:
#      Stock_Name       Date   Adj Close      Volume  Close in $  Open in $  \
# 0     Microsoft 1986-03-13    0.059947  1031788800      0.0972     0.0885
# 1     Microsoft 1986-03-14    0.062087   308160000      0.1007     0.0972
# 2     Microsoft 1986-03-17    0.063158   133171200      0.1024     0.1007
# 3     Microsoft 1986-03-18    0.061552    67766400      0.0998     0.1024
# 4     Microsoft 1986-03-19    0.060482    47894400      0.0981     0.0998
# ...         ...        ...         ...         ...         ...        ...
# 9743  Microsoft 2024-11-08  422.540009    16891400    422.5400   425.3200
# 9744  Microsoft 2024-11-11  418.010010    24503300    418.0100   422.5200
# 9745  Microsoft 2024-11-12  423.029999    19401200    423.0300   418.2500
# 9746  Microsoft 2024-11-13  425.200012    21502200    425.2000   421.6400
# 9747  Microsoft 2024-11-14  426.890015    30246900    426.8900   425.0000
#
#       High in $  Low in $  MA_Six_Months  MA_One_Year
# 0        0.1016    0.0885            NaN          NaN
# 1        0.1024    0.0972            NaN          NaN
# 2        0.1033    0.1007            NaN          NaN
# 3        0.1033    0.0990            NaN          NaN
# 4        0.1007    0.0972            NaN          NaN
# ...         ...       ...            ...          ...
# 9743   426.5000  421.7800     422.475792   387.420904
# 9744   424.8100  416.0000     422.562295   387.666438
# 9745   424.4400  417.2000     422.624481   387.914247
# 9746   429.3300  418.2100     422.705683   388.160274
# 9747   428.1700  420.0000     422.811421   388.409452
#
# [9748 rows x 10 columns]

# %%
netflix['MA_Six_Months'] = netflix['Close in $'].rolling(window=183).mean()
netflix['MA_One_Year'] = netflix['Close in $'].rolling(window=365).mean()
netflix
# Out:
#      Stock_Name       Date   Adj Close     Volume  Close in $  Open in $  \
# 0       Netflix 2002-05-23    1.196429  104790000      1.1964     1.1564
# 1       Netflix 2002-05-24    1.210000   11104800      1.2100     1.2143
# 2       Netflix 2002-05-28    1.157143    6609400      1.1571     1.2136
# 3       Netflix 2002-05-29    1.103571    6757800      1.1036     1.1643
# 4       Netflix 2002-05-30    1.071429   10154200      1.0714     1.1079
# ...         ...        ...         ...        ...         ...        ...
# 5655    Netflix 2024-11-08  795.039978    1910600    795.0400   797.3600
# 5656    Netflix 2024-11-11  805.440002    2399200    805.4400   795.9000
# 5657    Netflix 2024-11-12  819.500000    2814100    819.5000   807.5000
# 5658    Netflix 2024-11-13  830.469971    2767800    830.4700   822.6200
# 5659    Netflix 2024-11-14  837.260010    3038200    837.2600   833.6700
#
#       High in $  Low in $  MA_Six_Months  MA_One_Year
# 0        1.2429    1.1457            NaN          NaN
# 1        1.2250    1.1971            NaN          NaN
# 2        1.2321    1.1571            NaN          NaN
# 3        1.1643    1.0857            NaN          NaN
# 4        1.1079    1.0714            NaN          NaN
# ...         ...       ...            ...          ...
# 5655   799.0600  788.6500     655.975738   551.989534
# 5656   806.8200  795.5700     657.243989   553.113397
# 5657   820.3700  803.7500     658.506448   554.254137
# 5658   836.9900  820.5400     659.855683   555.432219
# 5659   841.0000  830.0200     661.219672   556.620493
#
# [5660 rows x 10 columns]

# %%
tesla['MA_Six_Months'] = tesla['Close in $'].rolling(window=183).mean()
tesla['MA_One_Year'] = tesla['Close in $'].rolling(window=365).mean()
tesla
# Out:
#      Stock_Name       Date   Adj Close     Volume  Close in $  Open in $  \
# 0         Tesla 2010-06-29    1.592667  281494500      1.5927     1.2667
# 1         Tesla 2010-06-30    1.588667  257806500      1.5887     1.7193
# 2         Tesla 2010-07-01    1.464000  123282000      1.4640     1.6667
# 3         Tesla 2010-07-02    1.280000   77097000      1.2800     1.5333
# 4         Tesla 2010-07-06    1.074000  103003500      1.0740     1.3333
# ...         ...        ...         ...        ...         ...        ...
# 3616      Tesla 2024-11-08  321.220001  204782800    321.2200   299.1400
# 3617      Tesla 2024-11-11  350.000000  210521600    350.0000   346.3000
# 3618      Tesla 2024-11-12  328.489990  155726000    328.4900   342.7400
# 3619      Tesla 2024-11-13  330.239990  125405600    330.2400   335.8500
# 3620      Tesla 2024-11-14  311.179993  120726100    311.1800   327.6900
#
#       High in $  Low in $  MA_Six_Months  MA_One_Year
# 0        1.6667    1.1693            NaN          NaN
# 1        2.0280    1.5533            NaN          NaN
# 2        1.7280    1.3513            NaN          NaN
# 3        1.5400    1.2473            NaN          NaN
# 4        1.3333    1.0553            NaN          NaN
# ...         ...       ...            ...          ...
# 3616   328.7100  297.6600     205.780929   222.445616
# 3617   358.6400  336.0000     206.629180   222.845808
# 3618   345.8400  323.3100     207.345464   223.177233
# 3619   344.6000  322.5000     208.101038   223.495781
# 3620   329.9800  310.3700     208.711858   223.752137
#
# [3621 rows x 10 columns]

# %% [markdown]
# Step 6: Checking For Duplicates

# %%
amazon[amazon.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Stock_Name, Date, Adj Close, Volume, Close in $, Open in $, High in $, Low in $, MA_Six_Months, MA_One_Year]
# Index: []

# %%
apple[apple.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Stock_Name, Date, Adj Close, Volume, Close in $, Open in $, High in $, Low in $, MA_Six_Months, MA_One_Year]
# Index: []

# %%
meta[meta.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Stock_Name, Date, Adj Close, Volume, Close in $, Open in $, High in $, Low in $, MA_Six_Months, MA_One_Year]
# Index: []

# %%
microsoft[microsoft.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Stock_Name, Date, Adj Close, Volume, Close in $, Open in $, High in $, Low in $, MA_Six_Months, MA_One_Year]
# Index: []

# %%
netflix[netflix.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Stock_Name, Date, Adj Close, Volume, Close in $, Open in $, High in $, Low in $, MA_Six_Months, MA_One_Year]
# Index: []

# %%
tesla[tesla.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Stock_Name, Date, Adj Close, Volume, Close in $, Open in $, High in $, Low in $, MA_Six_Months, MA_One_Year]
# Index: []

# %% [markdown]
# Step 7: Combine All Datasets

# %%
frames_stocks = [amazon,apple,meta,microsoft,netflix,tesla]

stocks = pd.concat(frames_stocks, axis = 0)
stocks
# Out:
#      Stock_Name       Date   Adj Close      Volume  Close in $  Open in $  \
# 0        Amazon 1997-05-15    0.097917  1443120000      0.0979     0.1219
# 1        Amazon 1997-05-16    0.086458   294000000      0.0865     0.0984
# 2        Amazon 1997-05-19    0.085417   122136000      0.0854     0.0880
# 3        Amazon 1997-05-20    0.081771   109344000      0.0818     0.0865
# 4        Amazon 1997-05-21    0.071354   377064000      0.0714     0.0818
# ...         ...        ...         ...         ...         ...        ...
# 3616      Tesla 2024-11-08  321.220001   204782800    321.2200   299.1400
# 3617      Tesla 2024-11-11  350.000000   210521600    350.0000   346.3000
# 3618      Tesla 2024-11-12  328.489990   155726000    328.4900   342.7400
# 3619      Tesla 2024-11-13  330.239990   125405600    330.2400   335.8500
# 3620      Tesla 2024-11-14  311.179993   120726100    311.1800   327.6900
#
#       High in $  Low in $  MA_Six_Months  MA_One_Year
# 0        0.1250    0.0964            NaN          NaN
# 1        0.0990    0.0854            NaN          NaN
# 2        0.0885    0.0812            NaN          NaN
# 3        0.0875    0.0818            NaN          NaN
# 4        0.0823    0.0688            NaN          NaN
# ...         ...       ...            ...          ...
# 3616   328.7100  297.6600     205.780929   222.445616
# 3617   358.6400  336.0000     206.629180   222.845808
# 3618   345.8400  323.3100     207.345464   223.177233
# 3619   344.6000  322.5000     208.101038   223.495781
# 3620   329.9800  310.3700     208.711858   223.752137
#
# [40169 rows x 10 columns]

# %%
stocks.dtypes
# Out:
# Stock_Name               object
# Date             datetime64[ns]
# Adj Close               float64
# Volume                    int64
# Close in $              float64
# Open in $               float64
# High in $               float64
# Low in $                float64
# MA_Six_Months           float64
# MA_One_Year             float64
# dtype: object

# %%
# Reordering Columns
stocks = stocks[['Date','Stock_Name','Volume','Close in $','Open in $','High in $','Low in $', 'MA_Six_Months', 'MA_One_Year']]
stocks
# Out:
#            Date Stock_Name      Volume  Close in $  Open in $  High in $  \
# 0    1997-05-15     Amazon  1443120000      0.0979     0.1219     0.1250
# 1    1997-05-16     Amazon   294000000      0.0865     0.0984     0.0990
# 2    1997-05-19     Amazon   122136000      0.0854     0.0880     0.0885
# 3    1997-05-20     Amazon   109344000      0.0818     0.0865     0.0875
# 4    1997-05-21     Amazon   377064000      0.0714     0.0818     0.0823
# ...         ...        ...         ...         ...        ...        ...
# 3616 2024-11-08      Tesla   204782800    321.2200   299.1400   328.7100
# 3617 2024-11-11      Tesla   210521600    350.0000   346.3000   358.6400
# 3618 2024-11-12      Tesla   155726000    328.4900   342.7400   345.8400
# 3619 2024-11-13      Tesla   125405600    330.2400   335.8500   344.6000
# 3620 2024-11-14      Tesla   120726100    311.1800   327.6900   329.9800
#
#       Low in $  MA_Six_Months  MA_One_Year
# 0       0.0964            NaN          NaN
# 1       0.0854            NaN          NaN
# 2       0.0812            NaN          NaN
# 3       0.0818            NaN          NaN
# 4       0.0688            NaN          NaN
# ...        ...            ...          ...
# 3616  297.6600     205.780929   222.445616
# 3617  336.0000     206.629180   222.845808
# 3618  323.3100     207.345464   223.177233
# 3619  322.5000     208.101038   223.495781
# 3620  310.3700     208.711858   223.752137
#
# [40169 rows x 9 columns]

# %% [markdown]
# Step 8: Exporting drafted dataframe

# %%
# Exporting drafted dataframe
stocks.to_csv(os.path.join(path, 'New Files', '6_Stocks_Transformed.csv'))
